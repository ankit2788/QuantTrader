# %%
from StrategyManager import YieldCurveDrivenStrategy
from importlib import reload
import numpy as np

# %%
reload(YieldCurveDrivenStrategy)
# Out:
# <module 'StrategyManager.YieldCurveDrivenStrategy' from '/Users/ankitgupta/Documents/git/anks/QuantTrader/StrategyManager/YieldCurveDrivenStrategy.py'>

# %%
mystgy = YieldCurveDrivenStrategy.YieldCurveRegimeDrivenStrategy(configFile = '/Users/ankitgupta/Documents/git/anks/QuantTrader/Config/YieldCurveConfig.ini')

# %%
mystgy.run(startDate = "20100101", endDate = "20221225")

# %%
mystgy.portfolioHistory
# Out:
#             Date         Cash  NIFTY CONSR DURBL  NIFTY BANK  NIFTY MIDCAP 50  \
# 0     2010-01-01      1000000               0.00        0.00             0.00
# 1     2010-01-02      1000000               0.00        0.00             0.00
# 2     2010-01-03      1000000               0.00        0.00             0.00
# 3     2010-01-04      1000000               0.00        0.00             0.00
# 4     2010-01-05      1000000               0.00        0.00             0.00
# ...          ...          ...                ...         ...              ...
# 4737  2022-12-21  1.24403e+06          782768.60   894976.95        760258.20
# 4738  2022-12-22   1.2016e+06          776895.65   932993.60        756195.30
# 4739  2022-12-23  1.12937e+06          759710.80   916697.10        730830.45
# 4740  2022-12-24  1.12937e+06          759710.80   916697.10        730830.45
# 4741  2022-12-25  1.08033e+06          808724.40   916697.10        730830.45
#
#       NIFTY INFRA    Cost  PortfolioValue       Price   Returns
# 0            0.00       0      1000000.00  100.000000       NaN
# 1            0.00       0      1000000.00  100.000000  0.000000
# 2            0.00       0      1000000.00  100.000000  0.000000
# 3            0.00       0      1000000.00  100.000000  0.000000
# 4            0.00       0      1000000.00  100.000000  0.000000
# ...           ...     ...             ...         ...       ...
# 4737    878946.75  124440      4560981.30  456.098130 -0.010556
# 4738    874194.75  124462      4541880.10  454.188010 -0.004188
# 4739    923103.00  124498      4459708.05  445.970805 -0.018092
# 4740    923103.00  124498      4459708.05  445.970805  0.000000
# 4741    923103.00  124522      4459683.54  445.968354 -0.000005
#
# [4742 rows x 10 columns]

# %%
mystgy.PortfolioManager.Trades
# Out:
#             Date              Asset  Quantity    Price    Cost
# 0     2010-01-31  NIFTY CONSR DURBL      98.0   2419.4  118.55
# 1     2010-01-31         NIFTY BANK      27.0   8651.5  116.80
# 2     2010-01-31    NIFTY MIDCAP 50      93.0   2539.2  118.07
# 3     2010-01-31        NIFTY INFRA      70.0   3374.7  118.11
# 4     2010-02-22  NIFTY CONSR DURBL     -98.0   2518.4  123.40
# ...          ...                ...       ...      ...     ...
# 1167  2022-12-14  NIFTY CONSR DURBL       3.0  25956.6   38.93
# 1168  2022-12-18    NIFTY MIDCAP 50      10.0   8831.4   44.16
# 1169  2022-12-22         NIFTY BANK       1.0  42408.8   21.20
# 1170  2022-12-23        NIFTY INFRA      14.0   5157.0   36.10
# 1171  2022-12-25  NIFTY CONSR DURBL       2.0  24506.8   24.51
#
# [1172 rows x 5 columns]

# %%
path = "/Users/ankitgupta/Documents/git/anks/Investing/StrategyRun/"


import os
import datetime
now = datetime.datetime.now().strftime("%Y%m%d")
mystgy.PortfolioManager.Trades.to_csv(os.path.join(os.path.join(path, f"{mystgy.__class__.__name__}_Trades_{now}.csv")))
mystgy.PortfolioManager.Trades.to_csv(os.path.join(os.path.join(path, f"{mystgy.__class__.__name__}_DailyAllData_{now}.csv")))

# %%
cumulativePerformance,annualPerformance,monthlyPerformance = mystgy.computePerformance()

# %%
cumulativePerformance
# Out:
#                      Stgy  Benchmark
# Returns            0.1220     0.0995
# Volatility         0.1018     0.1686
# Max Drawdown      -0.2703    -0.3844
# Sharpe Ratio       1.1980     0.5898
# Sortino Ratio      1.8044     0.9273
# Beta               0.5184     1.0000
# Tracking Error     0.1158     0.0000
# Information Ratio  0.1945        NaN

# %%
annualPerformance
# Out:
#      Returns (%)           Volatility (%)              Sharpe
#        benchmark  strategy      benchmark  strategy benchmark  strategy
# 2010    0.179485  0.281213       0.159989  0.100981  1.121860  2.784820
# 2011   -0.246182 -0.005303       0.204611  0.050354 -1.203171 -0.105312
# 2012    0.273885  0.177437       0.149055  0.125406  1.837478  1.414899
# 2013    0.067552  0.029147       0.176547  0.085485  0.382629  0.340962
# 2014    0.313880  0.294742       0.122643  0.116004  2.559301  2.540794
# 2015   -0.040615  0.040267       0.158059  0.076060 -0.256959  0.529409
# 2016    0.030140  0.146453       0.147405  0.092361  0.204470  1.585650
# 2017    0.286374  0.313693       0.088203  0.072865  3.246764  4.305112
# 2018    0.031263 -0.068262       0.124852  0.089397  0.250404 -0.763583
# 2019    0.120221  0.064517       0.133681  0.103865  0.899308  0.621159
# 2020    0.149016  0.133482       0.305902  0.163440  0.487137  0.816702
# 2021    0.241193  0.284041       0.152604  0.101279  1.580513  2.804526
# 2022    0.026089 -0.013813       0.170263  0.100673  0.153227 -0.137210

# %%
monthlyPerformance
# Out:
#         Returns (%)           Volatility (%)              Sharpe
#           benchmark  strategy      benchmark  strategy benchmark  strategy
# 2010-1    -0.061334 -0.000472       0.158106  0.001367 -0.387930 -0.345033
# 2010-2     0.004612 -0.013203       0.191302  0.162016  0.024109 -0.081494
# 2010-3     0.066392  0.066973       0.109181  0.085448  0.608089  0.783786
# 2010-4    -0.002362  0.034881       0.125471  0.099559 -0.018828  0.350359
# 2010-5    -0.026116 -0.000472       0.252557  0.001368 -0.103406 -0.345033
# ...             ...       ...            ...       ...       ...       ...
# 2022-8     0.024178  0.018536       0.131853  0.057541  0.183371  0.322129
# 2022-9    -0.025563 -0.021692       0.151735  0.105004 -0.168473 -0.206578
# 2022-10    0.066609  0.037804       0.127590  0.096253  0.522056  0.392755
# 2022-11    0.033780  0.008204       0.094556  0.037386  0.357248  0.219456
# 2022-12   -0.053459 -0.041853       0.109084  0.079133 -0.490072 -0.528892
#
# [156 rows x 6 columns]

# %%
mystgy.plot_performance()
