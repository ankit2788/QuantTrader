# %%
from StrategyManager import YieldCurveDrivenStrategy
from importlib import reload
import numpy as np

# %%
reload(YieldCurveDrivenStrategy)
# Out:
# <module 'StrategyManager.YieldCurveDrivenStrategy' from '/Users/ankitgupta/Documents/git/anks/QuantTrader/StrategyManager/YieldCurveDrivenStrategy.py'>

# %%
mystgy = YieldCurveDrivenStrategy.YieldCurveRegimeDrivenStrategy(configFile = '/Users/ankitgupta/Documents/git/anks/QuantTrader/Config/YieldCurveConfig2.ini')

# %%
mystgy.run(startDate = "20100101", endDate = "20221225")

# %%
mystgy.portfolioHistory
# Out:
#             Date         Cash  NIFTY CONSR DURBL  NIFTY BANK  NIFTY MIDCAP 50  \
# 0     2010-01-01      1000000               0.00        0.00              0.0
# 1     2010-01-02      1000000               0.00        0.00              0.0
# 2     2010-01-03      1000000               0.00        0.00              0.0
# 3     2010-01-04      1000000               0.00        0.00              0.0
# 4     2010-01-05      1000000               0.00        0.00              0.0
# ...          ...          ...                ...         ...              ...
# 4737  2022-12-21  1.26417e+06          530262.60   554033.35         367021.2
# 4738  2022-12-22  1.26417e+06          526284.15   551314.40         365059.8
# 4739  2022-12-23  1.20742e+06          514642.80   541684.65         352814.7
# 4740  2022-12-24  1.15838e+06          563656.40   541684.65         352814.7
# 4741  2022-12-25  1.15838e+06          563656.40   541684.65         352814.7
#
#       NIFTY INFRA  NIFTY METAL  NIFTY ENERGY     Cost  PortfolioValue  \
# 0            0.00          0.0          0.00        0      1000000.00
# 1            0.00          0.0          0.00        0      1000000.00
# 2            0.00          0.0          0.00        0      1000000.00
# 3            0.00          0.0          0.00        0      1000000.00
# 4            0.00          0.0          0.00        0      1000000.00
# ...           ...          ...           ...      ...             ...
# 4737    580637.55     672552.3     444130.10  85122.1      4412809.75
# 4738    577498.35     664963.5     439946.40  85122.1      4389239.25
# 4739    618840.00     635256.0     422959.15  85150.5      4293614.59
# 4740    618840.00     635256.0     422959.15    85175      4293590.08
# 4741    618840.00     635256.0     422959.15    85175      4293590.08
#
#            Price   Returns
# 0     100.000000       NaN
# 1     100.000000  0.000000
# 2     100.000000  0.000000
# 3     100.000000  0.000000
# 4     100.000000  0.000000
# ...          ...       ...
# 4737  441.280975 -0.012124
# 4738  438.923925 -0.005341
# 4739  429.361459 -0.021786
# 4740  429.359008 -0.000006
# 4741  429.359008  0.000000
#
# [4742 rows x 12 columns]

# %%
mystgy.PortfolioManager.Trades
# Out:
#            Date              Asset  Quantity    Price   Cost
# 0    2010-01-31  NIFTY CONSR DURBL      65.0   2419.4  78.63
# 1    2010-01-31         NIFTY BANK      18.0   8651.5  77.86
# 2    2010-01-31    NIFTY MIDCAP 50      62.0   2539.2  78.72
# 3    2010-01-31        NIFTY INFRA      46.0   3374.7  77.62
# 4    2010-01-31        NIFTY METAL      36.0   4281.7  77.07
# ..          ...                ...       ...      ...    ...
# 792  2022-12-16        NIFTY METAL      11.0   6657.7  36.62
# 793  2022-12-18    NIFTY MIDCAP 50       7.0   8831.4  30.91
# 794  2022-12-19       NIFTY ENERGY       2.0  26578.7  26.58
# 795  2022-12-23        NIFTY INFRA      11.0   5157.0  28.36
# 796  2022-12-24  NIFTY CONSR DURBL       2.0  24506.8  24.51
#
# [797 rows x 5 columns]

# %%
path = "/Users/ankitgupta/Documents/git/anks/Investing/StrategyRun/"


import os
import datetime
now = datetime.datetime.now().strftime("%Y%m%d")
mystgy.PortfolioManager.Trades.to_csv(os.path.join(os.path.join(path, f"{mystgy.__class__.__name__}_Trades_{now}.csv")))
mystgy.PortfolioManager.Trades.to_csv(os.path.join(os.path.join(path, f"{mystgy.__class__.__name__}_DailyAllData_{now}.csv")))

# %%
cumulativePerformance,annualPerformance,monthlyPerformance = mystgy.computePerformance()

# %%
cumulativePerformance
# Out:
#                      Stgy  Benchmark
# Returns            0.1187     0.0995
# Volatility         0.1123     0.1686
# Max Drawdown      -0.3289    -0.3844
# Sharpe Ratio       1.0573     0.5898
# Sortino Ratio      1.6070     0.9273
# Beta               0.5657     1.0000
# Tracking Error     0.1176     0.0000
# Information Ratio  0.1636        NaN

# %%
annualPerformance
# Out:
#      Returns (%)           Volatility (%)              Sharpe
#        benchmark  strategy      benchmark  strategy benchmark  strategy
# 2010    0.179485  0.262347       0.159989  0.117090  1.121860  2.240558
# 2011   -0.246182 -0.024009       0.204611  0.049758 -1.203171 -0.482526
# 2012    0.273885  0.112564       0.149055  0.120501  1.837478  0.934133
# 2013    0.067552 -0.001712       0.176547  0.089213  0.382629 -0.019185
# 2014    0.313880  0.330409       0.122643  0.149338  2.559301  2.212492
# 2015   -0.040615  0.042261       0.158059  0.089238 -0.256959  0.473578
# 2016    0.030140  0.188718       0.147405  0.092404  0.204470  2.042303
# 2017    0.286374  0.489291       0.088203  0.093570  3.246764  5.229125
# 2018    0.031263 -0.100033       0.124852  0.118042  0.250404 -0.847434
# 2019    0.120221  0.059647       0.133681  0.121675  0.899308  0.490213
# 2020    0.149016  0.031434       0.305902  0.169655  0.487137  0.185284
# 2021    0.241193  0.294264       0.152604  0.101577  1.580513  2.896940
# 2022    0.026089  0.004022       0.170263  0.098173  0.153227  0.040964

# %%
monthlyPerformance
# Out:
#         Returns (%)           Volatility (%)              Sharpe
#           benchmark  strategy      benchmark  strategy benchmark  strategy
# 2010-1    -0.061334 -0.000466       0.158106  0.001350 -0.387930 -0.345033
# 2010-2     0.004612 -0.011831       0.191302  0.168643  0.024109 -0.070154
# 2010-3     0.066392  0.067727       0.109181  0.087652  0.608089  0.772677
# 2010-4    -0.002362  0.014322       0.125471  0.103885 -0.018828  0.137865
# 2010-5    -0.026116 -0.000468       0.252557  0.001356 -0.103406 -0.345033
# ...             ...       ...            ...       ...       ...       ...
# 2022-8     0.024178  0.013612       0.131853  0.045660  0.183371  0.298127
# 2022-9    -0.025563 -0.025768       0.151735  0.109188 -0.168473 -0.236000
# 2022-10    0.066609  0.034022       0.127590  0.097874  0.522056  0.347604
# 2022-11    0.033780  0.007734       0.094556  0.038693  0.357248  0.199880
# 2022-12   -0.053459 -0.044959       0.109084  0.091244 -0.490072 -0.492733
#
# [156 rows x 6 columns]

# %%
mystgy.plot_performance()
